# %% [markdown]
# # (1-1)FRED 경제데이터가져오기)

# %%
pip install pandas-datareader
# Out:
# Collecting pandas-datareader
#   Using cached pandas_datareader-0.10.0-py3-none-any.whl (109 kB)
# Collecting requests>=2.19.0
#   Using cached requests-2.27.1-py2.py3-none-any.whl (63 kB)
# Collecting lxml
#   Downloading lxml-4.8.0-cp310-cp310-win_amd64.whl (3.6 MB)
#      ---------------------------------------- 3.6/3.6 MB 21.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.23 in c:\users\user\lib\site-packages (from pandas-datareader) (1.4.2)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\lib\site-packages (from pandas>=0.23->pandas-datareader) (1.22.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\lib\site-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\lib\site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      -------------------------------------- 149.2/149.2 KB 8.7 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      -------------------------------------- 139.0/139.0 KB 8.0 MB/s eta 0:00:00
# Collecting charset-normalizer~=2.0.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.3-py3-none-any.whl (61 kB)
# Requirement already satisfied: six>=1.5 in c:\users\user\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.23->pandas-datareader) (1.16.0)
# Installing collected packages: certifi, urllib3, lxml, idna, charset-normalizer, requests, pandas-datareader
# Successfully installed certifi-2021.10.8 charset-normalizer-2.0.12 idna-3.3 lxml-4.8.0 pandas-datareader-0.10.0 requests-2.27.1 urllib3-1.26.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas_datareader.data as web
import datetime
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2021, 6, 27)
gdp = web.DataReader('GDP', 'fred', start, end)

# %%
gdp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 46 entries, 2010-01-01 to 2021-04-01
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   GDP     46 non-null     float64
# dtypes: float64(1)
# memory usage: 736.0 bytes

# %%
gdp.describe()
# Out:
#                 GDP
# count     46.000000
# mean   18405.703457
# std     2248.229132
# min    14764.611000
# 25%    16472.552000
# 50%    18319.519500
# 75%    20405.298000
# max    22740.959000

# %%
gdp
# Out:
#                   GDP
# DATE
# 2010-01-01  14764.611
# 2010-04-01  14980.193
# 2010-07-01  15141.605
# 2010-10-01  15309.471
# 2011-01-01  15351.444
# 2011-04-01  15557.535
# 2011-07-01  15647.681
# 2011-10-01  15842.267
# 2012-01-01  16068.824
# 2012-04-01  16207.130
# 2012-07-01  16319.540
# 2012-10-01  16420.386
# 2013-01-01  16629.050
# 2013-04-01  16699.551
# 2013-07-01  16911.068
# 2013-10-01  17133.114
# 2014-01-01  17144.281
# 2014-04-01  17462.703
# 2014-07-01  17743.227
# 2014-10-01  17852.540
# 2015-01-01  17991.348
# 2015-04-01  18193.707
# 2015-07-01  18306.960
# 2015-10-01  18332.079
# 2016-01-01  18425.306
# 2016-04-01  18611.617
# 2016-07-01  18775.459
# 2016-10-01  18968.041
# 2017-01-01  19153.912
# 2017-04-01  19322.920
# 2017-07-01  19558.693
# 2017-10-01  19882.965
# 2018-01-01  20143.716
# 2018-04-01  20492.492
# 2018-07-01  20659.102
# 2018-10-01  20813.325
# 2019-01-01  21001.591
# 2019-04-01  21289.268
# 2019-07-01  21505.012
# 2019-10-01  21694.458
# 2020-01-01  21481.367
# 2020-04-01  19477.444
# 2020-07-01  21138.574
# 2020-10-01  21477.597
# 2021-01-01  22038.226
# 2021-04-01  22740.959

# %%
gdp.loc['2021-01-01']
# Out:
# GDP    22038.226
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
gdp.loc["2019-04-01"]
# Out:
# GDP    21289.268
# Name: 2019-04-01 00:00:00, dtype: float64

# %%
inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)

# %%
inflation
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962
# ...              ...       ...
# 2021-02-01   263.346   270.522
# 2021-03-01   265.028   271.347
# 2021-04-01   266.727   273.669
# 2021-05-01   268.599   275.715
# 2021-06-01   270.955   277.922
#
# [138 rows x 2 columns]

# %%
inflation.head()
# Out:
#             CPIAUCSL  CPILFESL
# DATE
# 2010-01-01   217.488   220.633
# 2010-02-01   217.281   220.731
# 2010-03-01   217.353   220.783
# 2010-04-01   217.403   220.822
# 2010-05-01   217.290   220.962

# %%
from pandas_datareader import wb
matches = wb.search('gdp.*capita.*const')

# %%
matches
# Out:
#                          id  \
# 716      6.0.GDPpc_constant
# 10389        NY.GDP.PCAP.KD
# 10391        NY.GDP.PCAP.KN
# 10393     NY.GDP.PCAP.PP.KD
# 10394  NY.GDP.PCAP.PP.KD.87
#
#                                                     name unit  \
# 716    GDP per capita, PPP (constant 2011 internation...
# 10389                 GDP per capita (constant 2015 US$)
# 10391                      GDP per capita (constant LCU)
# 10393  GDP per capita, PPP (constant 2017 internation...
# 10394  GDP per capita, PPP (constant 1987 internation...
#
#                              source  \
# 716                  LAC Equity Lab
# 10389  World Development Indicators
# 10391  World Development Indicators
# 10393  World Development Indicators
# 10394         WDI Database Archives
#
#                                               sourceNote  \
# 716    GDP per capita based on purchasing power parit...
# 10389  GDP per capita is gross domestic product divid...
# 10391  GDP per capita is gross domestic product divid...
# 10393  GDP per capita based on purchasing power parit...
# 10394
#
#                                       sourceOrganization            topics
# 716         b'World Development Indicators (World Bank)'  Economy & Growth
# 10389  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10391  b'World Bank national accounts data, and OECD ...  Economy & Growth
# 10393  b'International Comparison Program, World Bank...  Economy & Growth
# 10394                                                b''

# %%
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['US', 'CA', 'MX'], start=2005, end=2008)

# %%
dat
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2008    42063.633052
#               2007    42097.435120
#               2006    39776.179473
#               2005    38573.199765
# Mexico        2008     9181.399967
#               2007     9214.353534
#               2006     9142.804774
#               2005     8877.851291
# United States 2008    53688.365135
#               2007    54272.719553
#               2006    53782.297288
#               2005    52796.089816

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 12 entries, ('Canada', '2008') to ('United States', '2005')
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   NY.GDP.PCAP.KD  12 non-null     float64
# dtypes: float64(1)
# memory usage: 565.0+ bytes

# %%
import requests
import json
data = requests.get('https://api.stlouisfed.org/fred/series?series_id=GNPCA&api_key=43be4fc471782325cab7d47238bf8962&file_type=json')

# %%
data.json()
# Out:
# {'realtime_start': '2022-05-10',
#  'realtime_end': '2022-05-10',
#  'seriess': [{'id': 'GNPCA',
#    'realtime_start': '2022-05-10',
#    'realtime_end': '2022-05-10',
#    'title': 'Real Gross National Product',
#    'observation_start': '1929-01-01',
#    'observation_end': '2021-01-01',
#    'frequency': 'Annual',
#    'frequency_short': 'A',
#    'units': 'Billions of Chained 2012 Dollars',
#    'units_short': 'Bil. of Chn. 2012 $',
#    'seasonal_adjustment': 'Not Seasonally Adjusted',
#    'seasonal_adjustment_short': 'NSA',
#    'last_updated': '2022-03-30 07:55:26-05',
#    'popularity': 16,
#    'notes': 'BEA Account Code: A001RX\n\n'}]}

# %%
pip install datapungi_fed
# Out:
# Collecting datapungi_fed
#   Downloading datapungi_fed-0.3.1-py2.py3-none-any.whl (101 kB)
#      -------------------------------------- 101.1/101.1 KB 5.7 MB/s eta 0:00:00
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pandas in c:\users\user\lib\site-packages (from datapungi_fed) (1.4.2)
# Collecting pytest-html
#   Downloading pytest_html-3.1.1-py3-none-any.whl (14 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\lib\site-packages (from datapungi_fed) (4.11.1)
# Collecting pytest
#   Downloading pytest-7.1.2-py3-none-any.whl (297 kB)
#      ------------------------------------- 297.0/297.0 KB 19.1 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\user\lib\site-packages (from datapungi_fed) (2.27.1)
# Collecting html5lib
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 KB 6.8 MB/s eta 0:00:00
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      ---------------------------------------- 96.5/96.5 KB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: lxml in c:\users\user\lib\site-packages (from datapungi_fed) (4.8.0)
# Collecting pyyaml
#   Downloading PyYAML-6.0-cp310-cp310-win_amd64.whl (151 kB)
#      ---------------------------------------- 151.7/151.7 KB ? eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\lib\site-packages (from beautifulsoup4->datapungi_fed) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in c:\users\user\lib\site-packages (from html5lib->datapungi_fed) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\user\lib\site-packages (from html5lib->datapungi_fed) (0.5.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\lib\site-packages (from pandas->datapungi_fed) (1.22.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\lib\site-packages (from pandas->datapungi_fed) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\lib\site-packages (from pandas->datapungi_fed) (2022.1)
# Collecting iniconfig
#   Downloading iniconfig-1.1.1-py2.py3-none-any.whl (5.0 kB)
# Collecting atomicwrites>=1.0
#   Downloading atomicwrites-1.4.0-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: packaging in c:\users\user\lib\site-packages (from pytest->datapungi_fed) (21.3)
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting py>=1.8.2
#   Downloading py-1.11.0-py2.py3-none-any.whl (98 kB)
#      ---------------------------------------- 98.7/98.7 KB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.2.0 in c:\users\user\lib\site-packages (from pytest->datapungi_fed) (21.4.0)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\users\user\lib\site-packages (from pytest->datapungi_fed) (0.4.4)
# Collecting pytest-metadata
#   Downloading pytest_metadata-2.0.1-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\lib\site-packages (from requests->datapungi_fed) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\lib\site-packages (from requests->datapungi_fed) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\lib\site-packages (from requests->datapungi_fed) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\lib\site-packages (from requests->datapungi_fed) (2.0.12)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\user\lib\site-packages (from packaging->pytest->datapungi_fed) (3.0.8)
# Using legacy 'setup.py install' for pyperclip, since package 'wheel' is not installed.
# Installing collected packages: pyperclip, iniconfig, xlrd, tomli, pyyaml, py, pluggy, html5lib, atomicwrites, pytest, pytest-metadata, pytest-html, datapungi_fed
#   Running setup.py install for pyperclip: started
#   Running setup.py install for pyperclip: finished with status 'done'
# Successfully installed atomicwrites-1.4.0 datapungi_fed-0.3.1 html5lib-1.1 iniconfig-1.1.1 pluggy-1.0.0 py-1.11.0 pyperclip-1.8.2 pytest-7.1.2 pytest-html-3.1.1 pytest-metadata-2.0.1 pyyaml-6.0 tomli-2.0.1 xlrd-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import datapungi_fed as dpf
dpf('gnp')._meta
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 import datapungi_fed as dpf
# ----> 2 dpf('gnp')._meta
#
# File ~\lib\site-packages\datapungi_fed\__init__.py:15, in topCall.__call__(self, *args, **kwargs)
#      13 def __call__(self,*args,**kwargs):
#      14     coreClass = data()
# ---> 15     return(coreClass(*args,**kwargs))
#
# File ~\lib\site-packages\datapungi_fed\api.py:61, in data.__call__(self, *args, **kwargs)
#      60 def __call__(self,*args,**kwargs):
# ---> 61     return(self.series(*args,**kwargs))
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:41, in driverCore.__call__(self, *args, **kwargs)
#      40 def __call__(self,*args,**kwargs):
# ---> 41     out = self._ETFactory.extractTransformFactory[self.defaultQueryFactoryEntry](*args,**kwargs)
#      42     return(out)
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:106, in extractTransformFactory.selectDBQuery.<locals>.<lambda>(*args, **kwargs)
#     101 r'''
#     102   Fix a generic query to a query to dbName, creates a lambda that, from
#     103   args/kwargs creates a query of the dbName
#     104 '''
#     105 fun  = functools.partial(queryFun,dbName)
# --> 106 lfun = lambda *args,**kwargs: fun(**self.getQueryArgs(dbName,*args,**kwargs))
#     107 #add quick user tips
#     108 lfun.options = self.dbParams[dbName]['params']
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:98, in extractTransformFactory.query(self, *args, **kwargs)
#      97 def query(self,*args,**kwargs):
# ---> 98     return( self.ETDB.query(*args,**kwargs) )
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:158, in extractTransformDB.query(self, dbName, params, file_type, verbose, warningsOn)
#     156 warningsList = ['countPassLimit']  # warn on this events.
#     157 prefixUrl = self.dbParams[dbName]['urlSuffix']
# --> 158 output = self.queryApiCleanOutput(prefixUrl, dbName, params, warningsList, warningsOn, verbose)
#     159 return(output)
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:180, in extractTransformDB.queryApiCleanOutput(self, urlPrefix, dbName, params, warningsList, warningsOn, verbose)
#     177 retrivedData = requests.get(** { key:entry for key, entry in query.items() if key in ['params','url'] } )
#     179 #clean data
# --> 180 df_output,self._cleanCode = self.cleanOutput(dbName,query,retrivedData)
#     182 #print warning if there is more data the limit to download
#     183 for entry in warningsList:
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:227, in extractTransformDB.cleanOutput(self, dbName, query, retrivedData)
#     222 def cleanOutput(self,dbName,query,retrivedData):
#     223     r'''
#     224      This is a placeholder - specific drivers should have their own cleaning method
#     225      this generates self._cleanCode
#     226     '''
# --> 227     transformedOutput = self._transformData(self.dbGroup,dbName,self.dbParams,query,retrivedData)
#     228     return(transformedOutput)
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:259, in transformExtractedData.__call__(self, dbGroup, dbName, dbParams, query, retrivedData)
#     257 def __call__(self,dbGroup,dbName,dbParams,query,retrivedData):
#     258     if dbGroup == 'Series':
# --> 259         return( self.cleanOutputSeries(dbName,dbParams,query,retrivedData) )
#     260     if dbGroup == 'Geo':
#     261         return( self.cleanOutputGeo(dbName,dbParams,query,retrivedData) )
#
# File ~\lib\site-packages\datapungi_fed\driverCore.py:277, in transformExtractedData.cleanOutputSeries(self, dbName, dbParams, query, retrivedData)
#     275 dataKey = dbParams[dbName]['json key']
#     276 cleanCode = "df_output =  pd.DataFrame( retrivedData.json()['{}'] )".format(dataKey)
# --> 277 df_output = pd.DataFrame(retrivedData.json()[dataKey])  # TODO: deal with xml
#     278 if dbName == 'observations':
#     279     seriesID =  query['params_dict']['series_id'] #{ x.split('=')[0] : x.split('=')[1] for x in query['params'].split("&") }['series_id']
#
# KeyError: 'observations'

# %%
# !pip install full-fred
# Out:
# Collecting full-fred
#   Downloading full_fred-0.0.9a3-py3-none-any.whl (47 kB)
#      ---------------------------------------- 47.6/47.6 KB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas in c:\users\user\lib\site-packages (from full-fred) (1.4.2)
# Requirement already satisfied: requests in c:\users\user\lib\site-packages (from full-fred) (2.27.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\lib\site-packages (from pandas->full-fred) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\lib\site-packages (from pandas->full-fred) (2022.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\user\lib\site-packages (from pandas->full-fred) (1.22.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\lib\site-packages (from requests->full-fred) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\lib\site-packages (from requests->full-fred) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\lib\site-packages (from requests->full-fred) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\lib\site-packages (from requests->full-fred) (3.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\lib\site-packages (from python-dateutil>=2.8.1->pandas->full-fred) (1.16.0)
# Installing collected packages: full-fred
# Successfully installed full-fred-0.0.9a3

# %%
# !pytest
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.4, pytest-7.1.2, pluggy-1.0.0
# rootdir: C:\Users\user\Desktop\Ubion
# plugins: html-3.1.1, metadata-2.0.1
# collected 0 items
#
# ============================ no tests ran in 0.03s ============================

# %%
from full_fred.fred import Fred
fred = Fred('example_key.txt')
# 안되는 이유 찾기
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#       1 from full_fred.fred import Fred
# ----> 2 fred = Fred('example_key.txt')
#
# File ~\lib\site-packages\full_fred\fred.py:55, in Fred.__init__(self, api_key_file, observation_start, observation_end)
#      53 super().__init__()
#      54 if api_key_file is not None:
# ---> 55     self.set_api_key_file(api_key_file)
#      56 else:
#      57     self.api_key_file = api_key_file
#
# File ~\lib\site-packages\full_fred\fred_base.py:42, in FredBase.set_api_key_file(self, api_key_file)
#      40 if not os.path.isfile(api_key_file):
#      41     e = "Can't find %s on path" % api_key_file
# ---> 42     raise FileNotFoundError(e)
#      43 self.api_key_file = api_key_file
#      44 return True
#
# FileNotFoundError: Can't find example_key.txt on path

# %%
fred.get_api_key_file()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 fred.get_api_key_file()
#
# NameError: name 'fred' is not defined

# %%
fred.get_series_df('GDPPOT')
